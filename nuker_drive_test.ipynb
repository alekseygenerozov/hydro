# %%
import hydro
import nuker
import parker
import astropy.constants as const
import numpy as np

#Constants
G=const.G.cgs.value
M_sun=const.M_sun.cgs.value
kb=const.k_B .cgs.value
mp=const.m_p.cgs.value
h=const.h.cgs.value
pc=const.pc.cgs.value

#Setting up grid boundary--scaled to mass
def grid_bdry(M, temp=1.E7):
	ct=np.sqrt(kb*temp/mp)
	#Nominal Parker radius.
	rp=G*M/(2*ct**2)
	#For now grid boundaries will simply be hard-coded multiple of rp
	rmin=0.1*rp
	rmax=10.*rp
	return [rmin, rmax]

#Source term from quataert 2004. Essentially a broken power law
def quataert_src(rad, eta=-2., mdotw=6.7*10.**22, r1=2.4e17, r2=1.2e18):
    a=mdotw/(4.*np.pi)/((r2**(eta+3)-r1**(eta+3))/(eta+3))
    if rad<r2 and rad>r1:
        return a*rad**eta
    else:
        return 0.
    
def M_enc(rad):
    return 0.

# eta=0.1
# galaxy='NGC4551'
# rho_0=1.E-23
# temp=1.E7
# galaxies=nuker.nuker_params()
# gparams=galaxies[galaxy]

# M_enc=nuker.get_M_enc(gparams)
# q=nuker.get_q(gparams)
# rmin,rmax=grid_bdry(gparams['M'])

galaxies=nuker.nuker_params()
g1=nuker.Galaxy('NGC4551', galaxies, cgs=False)
rmin=0.1*g1.rinf
rmax=10.*g1.rinf


temp=2.e6
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=100, safety=0.6, Re=100.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=True,  movies=True)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))

# %%
import subprocess

def bash_command(cmd):
    process=subprocess.Popen(['/bin/bash', '-c',cmd],  stdin=subprocess.PIPE, stdout=subprocess.PIPE)
    return process.communicate()[0]
bash_command('mkdir /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2')
bash_command('./copy /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2')

rmin=0.1*g1.rinf
rmax=10.*g1.rinf
temp=2.e6
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=100, safety=0.6, Re=200.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=True,  movies=True)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
bash_command('mkdir /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_highRe')
bash_command('./copy /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_highRe')

# %%
rmin=0.1*g1.rinf
rmax=100.*g1.rinf


temp=2.e6
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=100, safety=0.6, Re=100.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=True,  movies=True)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))


bash_command('mkdir /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_largegrid')
bash_command('./copy /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_largegrid')

# %%
params=dict(n=100, safety=0.6, Re=100.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=False,  movies=True)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))


bash_command('mkdir /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_nonisot')
bash_command('./copy /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_nonisot')

# %%
rmin=0.1*g1.rinf
rmax=10.*g1.rinf
temp=2.e6
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=100, safety=0.6, Re=100.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=True,  movies=True)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
grid.solve(5*parker.tcross(rmin*pc, rmax*pc, temp))
bash_command('mkdir /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_longt')
bash_command('./copy /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_longt')

# %%
galaxies=nuker.nuker_params()
g1=nuker.Galaxy('NGC4551', galaxies, cgs=False, eta=100.)
b
rmin=0.2*g1.rinf
rmax=10.*g1.rinf
temp=2.e6
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=100, safety=0.6, Re=100.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=False,  movies=True, vw=10.**8)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], M_enc, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
bash_command('mkdir /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_highq_nomenc_nonisot_w')
bash_command('./copy /home/aleksey/Second_Year_Project/hydro/output/ngc4551/attempt_lowt2_highq_nomenc_nonisot_w')

# %%
import sys
sys.path.append('/home/aleksey/code/python/progressbar/progressbar')
import hydro
import nuker
import parker
import astropy.constants as const
import numpy as np


#Constants
G=const.G.cgs.value
M_sun=const.M_sun.cgs.value
kb=const.k_B .cgs.value
mp=const.m_p.cgs.value
h=const.h.cgs.value
pc=const.pc.cgs.value

x=(10**7.11)/(3.6*10.**6)

galaxies=nuker.nuker_params()
g1=nuker.Galaxy('NGC4551', galaxies, cgs=False, eta=0.5)


#Source term from quataert 2004. Essentially a broken power law
def quataert_src(rad, eta=-2., mdotw=6.7*10.**22, r1=2.4e17*x, r2=1.2e18*x):
    a=mdotw/(4.*np.pi)/((r2**(eta+3)-r1**(eta+3))/(eta+3))
    if rad<r2 and rad>r1:
        return a*rad**eta
    else:
        return 0.
    
def M_enc(rad):
    return 0.



rmin=3.8E16*x/pc
rmax=3.E18*x/pc


temp=1.e7
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=70, safety=0.6, Re=90.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=True,  movies=True, vw=0., qpc=True, params_delta=())

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], M_enc, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp), max_steps=1000)
grid.isot_off()
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
grid.Re=180.  
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
grid.Re=360.
grid.solve(4*parker.tcross(rmin*pc, rmax*pc, temp))
# grid.reset_vw(0.)
# grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))

# %%
# import subprocess

# def bash_command(cmd):
#     process=subprocess.Popen(['/bin/bash', '-c',cmd],  stdin=subprocess.PIPE, stdout=subprocess.PIPE)
#     return process.communicate()[0]


# bash_command('mkdir ngc4551_2/seq_isot_nisot_Rex2_novw')
# bash_command('./copy ngc4551_2/seq_isot_nisot_Rex2_novw')

# %%
# import hydro
# import nuker
# import parker
# import astropy.constants as const
# import numpy as np

# #Constants
# G=const.G.cgs.value
# M_sun=const.M_sun.cgs.value
# kb=const.k_B .cgs.value
# mp=const.m_p.cgs.value
# h=const.h.cgs.value
# pc=const.pc.cgs.value

# x=(10**7.11)/(3.6*10.**6)

# galaxies=nuker.nuker_params()
# g1=nuker.Galaxy('NGC4551', galaxies, cgs=False, eta=0.1)


# #Source term from quataert 2004. Essentially a broken power law
# def quataert_src(rad, eta=-2., mdotw=6.7*10.**22, r1=2.4e17*x, r2=1.2e18*x):
#     a=mdotw/(4.*np.pi)/((r2**(eta+3)-r1**(eta+3))/(eta+3))
#     if rad<r2 and rad>r1:
#         return a*rad**eta
#     else:
#         return 0.
    
# def M_enc(rad):
#     return 0.



# rmin=3.8E16*x/pc
# rmax=3.E18*x/pc


# temp=1.e7
# rho_0=1.E-23
# d=dict(rho_0=rho_0, temp=temp, log=True)
# params=dict(n=70, safety=0.6, Re=90.,  params=d,  floor=0.,
#     logr=True, symbol='r', isot=True,  movies=True, qpc=True, params_delta=())

# grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
# grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
# grid.isot_off()
# grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
# grid.Re=180. 
# grid.solve(4*parker.tcross(rmin*pc, rmax*pc, temp))

# bash_command('mkdir ngc4551_2/seq_isot_nisot_Rex2_novw_menc')
# bash_command('./copy ngc4551_2/seq_isot_nisot_Rex2_novw_menc')

# %%
import sys
sys.path.append('/home/aleksey/code/python/progressbar/progressbar')
import hydro
import nuker
import parker
import astropy.constants as const
import numpy as np

#Constants
G=const.G.cgs.value
M_sun=const.M_sun.cgs.value
kb=const.k_B .cgs.value
mp=const.m_p.cgs.value
h=const.h.cgs.value
pc=const.pc.cgs.value
c=const.c.cgs.value

x=(10**7.11)/(3.6*10.**6)

galaxies=nuker.nuker_params()
g1=nuker.Galaxy('NGC4551', galaxies, cgs=False, eta=0.5)


#Source term from quataert 2004. Essentially a broken power law
def quataert_src(rad, eta=-2., mdotw=6.7*10.**22, r1=2.4e17*x, r2=1.2e18*x):
    a=mdotw/(4.*np.pi)/((r2**(eta+3)-r1**(eta+3))/(eta+3))
    if rad<r2 and rad>r1:
        return a*rad**eta
    else:
        return 0.
    
def M_enc(rad):
    return 0.



rmin=3.8E16*x/pc
rmax=3.E18*x/pc


temp=1.e7
rho_0=1.E-23
d=dict(rho_0=rho_0, temp=temp, log=True)
params=dict(n=70, safety=0.6, Re=90.,  params=d,  floor=0.,
    logr=True, symbol='r', isot=True,  movies=True, vw=0., qpc=True, params_delta=(), Re_s=10.**20)

grid=hydro.Grid(rmin*pc, rmax*pc, parker.background, g1.params['M'], g1.M_enc_circ, g1.q, **params)
grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
# grid.isot_off()
# grid.solve(2*parker.tcross(rmin*pc, rmax*pc, temp))
# #grid.Re_s=1000.
# grid.Re=180.
# grid.solve(3*parker.tcross(rmin*pc, rmax*pc, temp))


# hydro.bash_command('./copy tmp')
# grid.Re_s=1000.
# grid.solve_adjust(2.5*parker.tcross(rmin*pc, rmax*pc, temp), 'vw', c*((grid.rg/grid.radii)*(grid.M_tot/grid.M_bh))**0.5)

# %%
grid.Re_s=1000.
grid.solve(parker.tcross(rmin*pc, rmax*pc, temp))

# %%
import pickle
pickle.dump( grid, open( "grid.p", "wb" ) )

# %%
import matplotlib.animation as animation

from tempfile import NamedTemporaryFile

VIDEO_TAG = """<video controls>
 <source src="data:video/x-m4v;base64,{0}" type="video/mp4">
 Your browser does not support the video tag.
</video>"""

def anim_to_html(anim):
    if not hasattr(anim, '_encoded_video'):
        with NamedTemporaryFile(suffix='.mp4') as f:
            anim.save(f.name, fps=20, extra_args=['-vcodec', 'libx264'])
            video = open(f.name, "rb").read()
        anim._encoded_video = video.encode("base64")
    
    return VIDEO_TAG.format(anim._encoded_video)

# %%
from IPython.display import HTML

def display_animation(anim):
    plt.close(anim._fig)
    return HTML(anim_to_html(anim))

# %%
#Create movie of solution
def animate(fname,  index=1, symbol='r', logx=True, logy=False, max_index=-1, ymin=None, ymax=None):
    ind_list=np.array([index]).flatten()
    sym_list=np.array([symbol]).flatten()
    saved=load(fname)['a']
    if not ymin:
        ymin=np.min(saved[:max_index,:,index])
    if not ymax:
        ymax=np.max(saved[:max_index,:,index])
    radii=saved[0,:,0]
    
    fig,ax=plt.subplots()
    if logx:
        ax.set_xscale('log')
    if logy:
        ax.set_yscale('log')
    ax.set_ylim(ymin-0.1*np.abs(ymin), ymax+0.1*np.abs(ymax))
    label=ax.text(0.02, 0.95, '', transform=ax.transAxes)	

    #Plot solution/initial condition/(maybe) analytic solution
    sol={}
    for i in range(len(ind_list)):
        sol[i],=ax.plot(radii, saved[0,:,ind_list[i]], symbol[i%len(sym_list)])
        #ax.plot(radii, saved[0,:,i], 'b')
    
    def update_img(n):
        for i in range(len(ind_list)):
            sol[i].set_ydata(saved[n*50,:,ind_list[i]])
        label.set_text(str(n))
    #Exporting animation
    sol_ani=animation.FuncAnimation(fig,update_img,len(saved[:max_index,:,index])/50,interval=50, blit=True)
    return sol_ani
    #sol_ani.save('sol_'+self.out_fields[index]+'.mp4', dpi=100)
    #plt.clf()

# %%
from scipy import integrate

frho=grid.get_field('frho')[1][grid.start:grid.end+2]
fluxes=np.diff(frho)

src=np.empty(grid.end-grid.start)
err=np.empty(grid.end-grid.start)
f=lambda r:r**2*g1.q(r/pc)/pc**3
for i in range(grid.start, grid.end):
    src[i-grid.start],err[i-grid.start]=integrate.quad(f, grid.radii[i], grid.radii[i+1])

# %%
loglog()
plot(grid.radii[grid.start:grid.end+1], abs(fluxes))
plot(grid.radii[grid.start:grid.end], src)
